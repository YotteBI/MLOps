# %%
import numpy
import matplotlib.pyplot as plt

# %%
a = numpy.array([1,2,3])
b = numpy.array([4,5,6])

# %%
a+b
# Out:
# array([-3, -3, -3])

# %%
a-b
# Out:
# array([-3, -3, -3])

# %%
a+10
# Out:
# array([11, 12, 13])

# %%
b+10
# Out:
# array([14, 15, 16])

# %%
a==b
# Out:
# array([False, False, False])

# %%
numpy.concatenate((a,b))
# Out:
# array([1, 2, 3, 4, 5, 6])

# %%
emp = numpy.arange(-10,11,1)**2

# %%
plt.plot(numpy.linspace(-10,10,1000),numpy.linspace(-10,10,1000)**2)

# %%
print(xsqr)
# Out:
# [100  81  64  49  36  25  16   9   4   1   0   1   4   9  16  25  36  49
#   64  81 100]

# %%
x = numpy.linspace(-10, 10, 1000)
f_x = 2 * x**2 + 3
g_x = -x**2

# %%
# Ajouter les légendes, titre et grilles

plt.plot(x, f_x, label="f(x) = 2x² + 3", color='blue')
plt.plot(x, g_x, label="g(x) = -x²", color='red')
plt.xlabel("x")
plt.ylabel("y")
plt.title("Représentation de 2x²+3 et -x²")
# Afficher le graphique
plt.show()
